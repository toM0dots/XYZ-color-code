# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/tomarr626/git/XYZ-color-code/XYZ_color_code/results/output.txt', sep=',', header= None, names=['T', 'x', 'y', 't'],dtype= {'T': np.float64, 'x': int, 'y': int, 't': np.float64})
# T = df['x'].to_numpy()
# N = df['y'].to_numpy()
# print(T)
# print(N)
t = df['t'].to_numpy()
t[0]
# Out:
# np.float64(5455.95)

# %%
df1 = pd.read_csv('/Users/tomarr626/git/XYZ-color-code/XYZ_color_code/T_mem.txt', sep=',', header= None, names=['m', 'n'],dtype= {'m': np.float64, 'n': np.float64})
M = df1['m'].to_numpy()
N = df1['n'].to_numpy()

# %%
df2 = pd.read_csv('/Users/tomarr626/git/XYZ-color-code/XYZ_color_code/repo_result.txt', sep=',',skiprows=1, header= None, names=['T2','p','x2', 'y2', 't2'],dtype= {'T2': np.float64, 'p': np.float64, 'x': int, 'y': int, 't': np.float64})

# %%
t2 = df2['t2'].to_numpy()
tt = []
# print(np.median(tt))
for i in range(500):
    tt.append(t2[2*i])
print(np.median(tt))
# Out:
# 50276.15

# %%
t0 = np.median(t[0:999])
t1 = np.median(t[2000:2999])
t2 = np.median(t[4000:4999])
t3 = np.median(t[6000:6999])
t4 = np.median(t[8000:8999])
t5 = np.median(t[10000:10999])
t0_6 = np.median(t[12000:12999])
t1_6 = np.median(t[14000:14999])
t2_6 = np.median(t[16000:16999])
t3_6 = np.median(t[18000:19999])
t4_6 = np.median(t[20000:20499])
t5_6 = np.median(t[20500:-1])

e0 = np.std(t[0:1999])
e1 = np.std(t[2000:3999])
e2 = np.std(t[4000:5999])
e3 = np.std(t[6000:7999])
e4 = np.std(t[8000:9999])
e5 = np.std(t[10000:11999])
e0_6 = np.std(t[12000:13999])
e1_6 = np.std(t[14000:15999])
e2_6 = np.std(t[16000:17999])
e3_6 = np.std(t[18000:19999])
e4_6 = np.std(t[20000: 20499])
e5_6 = np.std(t[20500:-1])

times = [t0, t1, t2, t3, t4, t5]
times_6 = [t0_6, t1_6, t2_6, t3_6, t4_6, t5_6]

errors = [e0, e1, e2, e3, e4, e5]
errors = np.array(errors)/ np.sqrt(500)
errors_6 = [e0_6, e1_6, e2_6, e3_6, e4_6, e5_6]
errors_6 = np.array(errors_6)/ np.sqrt(500)
x1 =[ 9*6*2, 12*9*2, 15*12*2, 18*15*2, 24*21*2, 27*24*2, 30*27*2, 33*30*2, 39*36*2]
print(t0, t1, t2, t3, t4)
print(np.mean(t[0:1999]))
print(np.mean(t[2000:3999]))
print(np.mean(t[4000:5999]))
print(np.mean(t[6000:7999]))
print(np.mean(t[8000:9999]))
print(t0_6)
print(t1_6)
print(t2_6)
print(t3_6)
print(errors)
print(errors_6)
# Out:
# 61966.6 125243.0 204606.0 231759.0 204493.0
# 90439.9588624312
# 185164.04982491248
# 292373.2798194097
# 326614.59254627314
# 291853.62082041026
# 104284.0
# 284636.0
# 537059.0
# 692198.0
# [ 4067.9163196   8295.19478429 13465.42886154 13721.20541971
#  12677.0387009  12998.29891141]
# [ 6604.07015012 17616.22224915 36628.41204477 46281.11951745
#  46360.81359944 55266.73404347]

# %%
y_cluster_median = [122699.3019253735, 304255.8568764945 , 493868.24200684356, 621684.0934445742, 661746.442777657]
y_cluster_median_errors = np.array([3718.1143384752895,  9930.040318360163 , 16665.511106320093, 40190.22213626109, 45674.22014455793])
repo_median = [117955.5, 256861.0, 406520.0, 424424.0]

# %%
plt.figure(figsize=(10, 4))
# plt.plot(x1[:len(times)], times, 'o-', label=r'$t_{mem}$ median dE = 3', linewidth=2)
# plt.errorbar(x1[:len(times)], times, yerr=errors, fmt='o', label=r'error dE = 3', linewidth=2)
plt.plot(x1[:len(times_6)], times_6, 'o-', label=r'$t_{mem}$ repo dE =6', linewidth=2)
plt.errorbar(x1[:len(times_6)], times_6, yerr=errors_6, fmt='o', label=r'error dE = 6', linewidth=2)
plt.plot(x1[:len(y_cluster_median)], y_cluster_median, 'o-', label=r'$t_{mem}$ python dE=3', linewidth=2)
plt.errorbar(x1[:len(y_cluster_median)], y_cluster_median, yerr=y_cluster_median_errors, fmt='o', label='python error dE=3', linewidth=2)
plt.plot(M, N, 'o-', label='Figure 4')
plt.plot(x1[:len(repo_median)], repo_median, 'o-', label=r'$t_{mem}$ repo dE=3', linewidth=2)
plt.xlabel('N')
plt.ylabel('T')
plt.xscale('log')
plt.yscale('log')
plt.title(r'$T_{mem}$ vs N on error rate $10^{-4}$')
# plt.ylim(1e, 1e6)
plt.grid()
plt.legend()
plt.savefig('T_mem_vs_N.png')
plt.show()

# %%
times_6
# Out:
# [np.float64(104284.0),
#  np.float64(284636.0),
#  np.float64(537059.0),
#  np.float64(692198.0),
#  np.float64(730030.0),
#  np.float64(844515.5)]

# %%
def normalize(data:list):
    mini = min(data)
    return [data[i]-mini for i in range(len(data))]

# %%
a, b = np.polyfit(y_cluster_median, times_6[:5], deg =1)
plt.plot(y_cluster_median, times_6[:-1], 'o-', label=r'$t_{python}$ vs t_{repo}', linewidth=2)
plt.plot(y_cluster_median, a*np.array(y_cluster_median) +b, '--', label=f'$fit = {a} y + {b}')
# plt.plot(y_cluster_median, 1.18935525*np.array(y_cluster_median)+-5.46868005e+04, '--', label = 'fit = 1.189a -54686')
plt.xlabel('python y')
plt.ylabel('repo y')
plt.legend()

# %%
y_me = np.log(y_cluster_median)
y_repo = np.log(times_6)[:5]
a, b = np.polyfit(y_me, y_repo, deg =1)
tau_fit = np.exp(b) * y_cluster_median ** a
# plt.plot(y_cluster_median, times_6[:-1], 'o-', label=r'$t_{python}$ vs t_{repo}', linewidth=2)
plt.plot(y_me, y_repo, 'o-', label=r'$y_{python} VS y_{repo}$')
plt.plot(y_me, a*np.array(y_me) +b, '--', label=f'$fit = {a} y + {b}')
# plt.plot(y_cluster_median, 1.18935525*np.array(y_cluster_median)+-5.46868005e+04, '--', label = 'fit = 1.189a -54686')
plt.xlabel('python y')
plt.ylabel('repo y')
plt.legend()

# %%
y_repo- (a*np.array(y_me) +b)
# Out:
# array([ 0.0147333 , -0.04263903,  0.02606969,  0.01080863, -0.00897258])

# %%
plt.plot(y_cluster_median, times_6[:-1], 'o-', label=r'$t_{python}$ vs t_{repo}', linewidth=2)
# plt.plot(y_cluster_median, N[:5])
23465840195, 379771.86551659065, 52123.15154727493, 348636.0699561347, 92425.63202676421, 344779.5916000752, 218190.96476346813, 6780.3760483903525, 52578.1472721702, 745985.6871461585, 130353.09019730097, 98286.57408871467, 1347974.4938638757, 320323.7061557614, 108819.96271823079, 1250144.8753491316, 15022.95889677589, 288353.96186514857, 437385.94194153644, 53588.41464333637, 111476.58781675535, 210511.20366099168, 305025.35326111654, 67066.25932346679, 19785.87128302813, 504436.6483769786, 92423.67638196555, 296323.6441565987, 733622.7542064867, 610972.7946546209, 314461.6026809623, 458096.01924391655, 56791.48102884249, 422822.0560486071, 115783.40694803411, 197670.9665667435, 85005.58819891934, 118439.75264678117, 14749.88028376835, 200147.16142662952, 348721.6053993835, 179076.47874055913, 574234.7612676531, 68425.48296336664, 34647.96301632337, 1224409.0754373951, 72918.17809963609, 450117.96449342143, 267103.61686753674, 662811.4513752925, 250798.4652273895, 149953.14305075616, 23176.465967977976, 164056.25743136456, 450210.2497023807, 477048.31447013223, 181550.24277289206, 514605.73675137287, 1235309.8684953079, 96912.40348725031, 874498.562187365, 269210.61266343924, 25563.274356179943, 399464.1441319445, 80881.99909491207, 109191.00981189837, 61744.26164386151, 140517.6256940521, 420720.8875856035, 317853.26909561636, 312721.4130551714, 212879.1709340096, 444992.01271376177, 124849.9105946869, 204732.25214518473, 96640.0021417287, 49280.37293613675, 184664.71516822133, 560953.786356187, 673345.0383933134, 93156.5241886709, 236326.3860714954, 67966.57011435705, 505722.3604609214, 375559.2491817657, 130529.01510246012, 320048.0462827961]

plt.hist(x, bins =700)
plt.xscale('log')

# %%
(tau_fit - times_6[:5])/np.array(times_6[:5])
# Out:
# array([-0.01462529,  0.04356113, -0.02573281, -0.01075043,  0.00901296])

# %%
plt.plot(x1[:len(times_6)], normalize(times_6), 'o-', label=r'$t_{mem}$ median dE =6', linewidth=2)
# plt.errorbar(x1[:len(times_6)], times_6, yerr=errors_6, fmt='o', label=r'error dE = 6', linewidth=2)
plt.plot(x1[:len(y_cluster_median)], normalize(y_cluster_median), 'o-', label='python median dE=3', linewidth=2)
# plt.errorbar(x1[:len(y_cluster_median)], y_cluster_median, yerr=y_cluster_median_errors, fmt='o', label='python error dE=3', linewidth=2)
plt.plot(M, normalize(N), 'o-', label='Figure 4')
plt.xlabel('N')
plt.ylabel('T')
plt.xscale('log')
# plt.yscale('log')
plt.title(r'$T_{mem}$ vs N on error rate $10^{-4}$')
plt.ylim(0, 0.6e6)
plt.xlim(0, 700)
plt.grid()
plt.legend()
plt.savefig('T_mem_vs_N.png')
plt.show()
# Out:
# /var/folders/b0/yd0t1s1d3csclx8j2np0lfvc0000gn/T/ipykernel_19089/1872539303.py:12: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.xlim(0, 700)

# %%
# plt.plot(x1[:len(times_6)-1], [a / b for a, b in zip(np.array(y_cluster_median)-times_6[:-1], times_6[:-1])], 'o-', label=r'$t_{mem}$ median dE =6', linewidth=2)
plt.plot(x1[:len(times_6)-1], (np.array(y_cluster_median)-times_6[:-1]), 'o-', label=r'$t_{mem}$ median dE =6', linewidth=2)
# plt.plot(M, N, 'o-', label='Figure 4')

# %%
print(N[:4]-times_6)
# Out:
# [-15706.91141727  -5930.47192279 -74552.8332472   -5777.22713605]

# %%
# N vs equilibrium energy for error rate 0.08 

N = [3*3, 4*4, 6*3, 5*5, 6*6, 9*6, 9*9, 12*12, 15*15, 18*18, 21*21, 24*24, 27*27, 30*30, 33*33, 36*36, 39*39]
E_08 = [0.32, 0.29, 0.28, 0.26, 0.25,0.245, 0.24, 0.23, 0.23, 0.23, 0.23 ]
E_008 =[0.25, 0.2, 0.19, 0.18, 0.156, 0.145, 0.137, 0.128, 0.127 ]
y1 = 1/(1+ np.exp(1.2168))
y2 = 1/(1+ np.exp(1.9844))
y3 = 1/(1+ np.exp(beta))

# %%
y3
# Out:
# np.float64(0.2983885804255796)

# %%
import math
beta = math.log((3+0.25)/0.25)/3
1/beta
# Out:
# 1.16961373575384

# %%
plt.plot(N[:len(E_08)], E_08, 'o-', label='N vs E_eq at error rate 0.08/ beta 1.2168', linewidth=2)
plt.axhline(y=y1, color='g', linestyle='--', label=r'$\frac{1}{1 + e^{1.2168}}$')
plt.plot(N[:len(E_008)], E_008, 'o-', label='N vs E_eq at error rate 0.008/ beta 1.98441444476', linewidth=2)
plt.axhline(y=y2, color='g', linestyle='--', label=r'$\frac{1}{1 + e^{1.98441444476}}$')
plt.xlabel('N')
plt.ylabel('E_eq')
plt.title('the finite size effect on E_eq')
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.legend()

# %%
arr = np.loadtxt('/Users/tomarr626/git/XYZ-color-code/XYZ_color_code/results/mags.csv', delimiter=',', skiprows=1, dtype=float)
t, M, E = arr.T   # transpose into three 1D arrays

# %%
import math
e = np.array(E)
l = 8
# N = l*l
N =3*2
energy = np.arange(N)
error_rate = 0.003
beta = math.log((3+error_rate)/error_rate)/3
n, bins = np.histogram(e[3000::20], bins=np.arange(N+1))
centers = 0.5*(bins[:-1] + bins[1:])


dos = [math.comb(N, int(en)) for en in energy]
factor = dos* np.exp(-beta * energy)
P = factor/ sum(factor)
counts = len(E[2000::20])

eq_E = 1/ (1 + np.exp(beta)) * N
eq_E_MC = np.mean(E[2000::30])

# %%
integral = 0
for i in range(64):
    integral += factor[i] * (bins[i+1] - bins[i])

print(integral)
# Out:
# 7.836533670558978

# %%
np.sum(n)/counts
# Out:
# np.float64(1.0)

# %%
# plt.hist(E[3000:]/64, bins=50, density = True)
plt.scatter(energy, P  , label='theoretical prediction, n(E)* exp( -beta * E)/ Z', s =10, color = 'r')
plt.scatter(energy, n/counts, label='MC histogram of E' , alpha = 0.5, s =10)
plt.axvline(x=eq_E, color='g', linestyle='--', label=r'$E_{eq}$ theoretical')
plt.axvline(x=eq_E_MC, color='b', linestyle='--', label=r'$E_{eq}$ MC simulation')
plt.xlabel('Energy')
plt.ylabel('Counts')
plt.legend()
# plt.ylim(0, 50)
plt.title(f'Energy histogram at equilibrium for 3*2, error rate {error_rate}')
# Out:
# Text(0.5, 1.0, 'Energy histogram at equilibrium for 3*2, error rate 0.003')

# %%
plt.plot(energy, P - n/counts, 'o')

# %%
energy = np.linspace(0, 0.35, 1000)
fac = np.exp(-beta * energy)
plt.plot(energy, fac/ np.sum(fac), label='theoretical prediction', color = 'g')
